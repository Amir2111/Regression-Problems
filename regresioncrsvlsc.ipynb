# %%
import pandas as pd
import numpy as np
# List to maintain the different cross-validation scores 
cross_val_scores_ridge = [] 
  
# List to maintain the different values of alpha 
alpha = [] 

data  = pd.read_csv("/content/sample_data/insurance.csv")
# change the value of "sex" into female:0, male:1
sex_change = {"sex":{"female":0, "male":1}
              }
data.replace(sex_change, inplace=True)
data['sex'].astype("category")

# change the value of "smoker" into "no":0,"yes":1
sm_change = {"smoker":{"no":0,"yes":1}
}
data.replace(sm_change,inplace=True)
data['smoker'].astype("category")

# change the value of "region" into  "southwest":0, "northwest":1,"southeast":2,"northeast":4
reg_change = {"region":{"southwest":0, "northwest":1,"southeast":2,"northeast":4}}
data.replace(reg_change, inplace=True)
data['region'].astype("category")

# Print(data.head())
x_input  = data.iloc[:, 0:6]
y_output = data.iloc[:, 6]

from sklearn.model_selection import train_test_split, cross_val_score
x_train ,x_test, y_train,y_test = train_test_split(x_input,y_output,test_size = 20)
 
# Loop to compute the different values of cross-validation scores 
from sklearn.linear_model import Ridge
for i in range(1, 9): 
    ridgeModel = Ridge(alpha = i * 0.25) 
    ridgeModel.fit(x_train, y_train) 
    scores = cross_val_score(ridgeModel, x_input, y_output, cv = 10)
    from statistics import mean  
    avg_cross_val_score = mean(scores)*100
    cross_val_scores_ridge.append(avg_cross_val_score) 
    alpha.append(i * 0.25) 
  
# Loop to print the different values of cross-validation scores 
for i in range(0, len(alpha)): 
    print(str(alpha[i])+' : '+str(cross_val_scores_ridge[i])) 

print(y_pred)
from sklearn.metrics import mean_squared_error

print("mean squared error:",mean_squared_error(y_test,y_pred))
# Out:
# 0.25 : 74.43613166104194
# 0.5 : 74.4366279750226
# 0.75 : 74.43691464812218
# 1.0 : 74.43699329201182
# 1.25 : 74.43686550593783
# 1.5 : 74.43653287682811
# 1.75 : 74.43599697939764
# 2.0 : 74.4352593762529
# [ 6936.08721944 13570.69981816  7124.7818396  10965.69748911
#  16631.57932666  4382.25279381 14288.15005521 36171.3515525
#  10024.92553959 36592.69711558  8858.99509898  3788.69429074
#   3968.01852518 12201.29788144 14958.94678026  5784.16419508
#  11622.69065881 12243.41511345 10175.90567079  4775.45461432]
# mean squared error: 211672909.8115506
